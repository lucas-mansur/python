# %% [markdown]
# # Exercícios
#
# ## 1. Calculando % de uma lista
#
# Faremos algo parecido com "filtrar" uma lista. Mais pra frente no curso aprenderemos outras formas de fazer isso, mas com o nosso conhecimentoa atual já conseguimos resolver o desafio.
#
# Digamos que a gente tenha uma lista de vendedores e ao invés de saber todos os vendedores que bateram a meta, eu quero conseguir calcular o % de vendedores que bateram a meta. Ou seja, se temos 10 vendedores e 3 bateram a meta, temos 30% dos vendedores que bateram a meta.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]

#seu código aqui
vendedores_meta=0
vendedores_meta_lista = []
for i in range(len(vendas)):
    
    if vendas[i][1] > meta:
        vendedores_meta+=1
        vendedores_meta_lista.append(vendas[i])

print(f"Percentual de vendedores que bateram a meta foi {vendedores_meta/len(vendas):.2%}")
print(f"Percentual de vendedores que bateram a meta foi {len(vendedores_meta_lista)/len(vendas):.2%}")
# Out:
# Percentual de vendedores que bateram a meta foi 50.00%
# Percentual de vendedores que bateram a meta foi 50.00%

# %% [markdown]
# - Vamos resolver de 2 formas:
#     1. Criando uma lista auxiliar apenas com os vendedores que bateram a meta
#     2. Fazendo o cálculo diretamente na lista que já temos

# %% [markdown]
# ## Para treinar uma estrutura parecida, crie um código para responder: quem foi o vendedor que mais vendeu?

# %%
vendas[0][1] > vendas[1][1]
# Out:
# False

# %%
#seu código aqui

meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]


vendedor_maior_venda = vendas[0]
for i in range(len(vendas)):
    if (vendedor_maior_venda[1]) >= (vendas[i][1]):
        continue
    else:
        vendedor_maior_venda = vendas[i]
    
print(vendedor_maior_venda)
# Out:
# ['Julia', 27000]
